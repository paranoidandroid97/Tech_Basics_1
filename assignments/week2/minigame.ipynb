# %%
import time
number = int(input("Hello Adventurer! When you're ready to begin just type in a 1"))
if number == 1:
    print("""
 _____                    _
|_   _|__ _ __ ___  _ __ | | ___
  | |/ _ \\ '_ ` _ \\| '_ \\| |/ _ \\
  | |  __/ | | | | | |_) | |  __/
  |_|\\___|_|_|_| |_| .__/|_|\\___|
   / \\   __| |_   _|_|_ _ __ | |_ _   _ _ __ ___
  / _ \\ / _` \\ \\ / / _ \\ '_ \\| __| | | | '__/ _ \\
 / ___ \\ (_| |\\ V /  __/ | | | |_| |_| | | |  __/
/_/   \\_\\__,_| \\_/ \\___|_| |_|\\__|\\__,_|_|  \\___|
""")
    time.sleep(1)
    print("Welcome to the Minigame!")
    time.sleep(1)
    print("Hope this is not gonna be the most stereotypical adventure full of chliche's.")
    time.sleep(3)
    print("So let me think of something...")
    time.sleep(8)
    print("Wait a second my god, and no the game isn't broken!")
    time.sleep(3)
    print("You're probably one of these TikTok kiddies. I can tell from you're attention span.")
    time.sleep(3)
    print("Oh haha, yeah I know a great, non cliche start to this adventure!")
    time.sleep(2)
    print("Here we go!")

    # Now the first scene starts
    time.sleep(3)
    print("""
You awaken in a dark forest. The trees whisper in the wind.
Two paths lie before you...
""")
    time.sleep(5)
    print("""
        ||      ||
        ||      ||
     ___||______||___
    /             /\\
   /             /  \\
  /      1      /    \\
 /             \\    /
/_______2_______\\__/
""")
    time.sleep(1)

    choice = input("Do you take path 1 (left) or path 2 (right)? Type 1 or 2: ")

    if choice == "1":
        print("\nYou walk down the left path and hear the howling of wolves...")
        # hier kannst du weiterschreiben für den linken Pfad
    elif choice == "2":
        print("\nYou follow the right path and see the glow of a mysterious light...")
        # hier kannst du weiterschreiben für den rechten Pfad
    else:
        print("You must choose 1 or 2 to proceed on your adventure!")

else:
    print("You must type in a 1 to begin your adventure :)")
    time.sleep(2)
    print("Start again but this time try to read")
# Out:
#  _____                    _
# |_   _|__ _ __ ___  _ __ | | ___
#   | |/ _ \ '_ ` _ \| '_ \| |/ _ \
#   | |  __/ | | | | | |_) | |  __/
#   |_|\___|_|_|_| |_| .__/|_|\___|
#    / \   __| |_   _|_|_ _ __ | |_ _   _ _ __ ___
#   / _ \ / _` \ \ / / _ \ '_ \| __| | | | '__/ _ \
#  / ___ \ (_| |\ V /  __/ | | | |_| |_| | | |  __/
# /_/   \_\__,_| \_/ \___|_| |_|\__|\__,_|_|  \___|
#
# Welcome to the Minigame!
# Hope this is not gonna be the most stereotypical adventure full of chliche's.
# So let me think of something...
# Wait a second my god, and no the game isn't broken!
# You're probably one of these TikTok kiddies. I can tell from you're attention span.
# Oh haha, yeah I know a great, non cliche start to this adventure!
# Here we go!
#
# You awaken in a dark forest. The trees whisper in the wind.
# Two paths lie before you...
#
#
#         ||      ||
#         ||      ||
#      ___||______||___
#     /             /\
#    /             /  \
#   /      1      /    \
#  /             \    /
# /_______2_______\__/
#
#
# You follow the right path and see the glow of a mysterious light...
